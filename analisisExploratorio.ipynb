# %% [markdown]
# ## ANÁLISIS EXPLORATORIO

# %%
import pandas as pd
import numpy as np
# import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# pip install pandas==1.4.3 --upgrade
pd.__version__
# Out:
# '1.3.5'

# %%
df = pd.read_csv("C:/Users/annal/Desktop/Catedrades/data2017_2022.csv", encoding="ISO 8859-15" ,sep=",",low_memory=False)
df
# Out:
#               FECHA  HORA  SO2   CO   NO  NO2   NOx    O3  \
# 0        01/01/2017     0  3.0  0,1  2.0  8.0  11.0  32.0
# 1        01/01/2017     1  3.0  NaN  2.0  9.0  11.0  31.0
# 2        01/01/2017     2  3.0  NaN  2.0  9.0  11.0  31.0
# 3        01/01/2017     3  3.0  NaN  2.0  9.0  12.0  31.0
# 4        01/01/2017     4  3.0  NaN  2.0  8.0  10.0  31.0
# ...             ...   ...  ...  ...  ...  ...   ...   ...
# 2890227  31/05/2022    19  3.0  NaN  1.0  1.0   2.0  96.0
# 2890228  31/05/2022    20  3.0  NaN  1.0  1.0   2.0  85.0
# 2890229  31/05/2022    21  3.0  NaN  1.0  1.0   2.0  58.0
# 2890230  31/05/2022    22  3.0  NaN  1.0  1.0   2.0  45.0
# 2890231  31/05/2022    23  3.0  NaN  1.0  1.0   2.0  51.0
#
#                          EstaciÃ³n C7H8  ... PM2.5  PM1 Veloc.mÃ¡x.  H2S NH3  \
# 0        Alcoi - Verge dels Lliris  NaN  ...   NaN  NaN         NaN  NaN NaN
# 1        Alcoi - Verge dels Lliris  NaN  ...   NaN  NaN         NaN  NaN NaN
# ...

# %%
df.columns
# Out:
# Index(['FECHA', 'HORA', 'SO2', 'CO', 'NO', 'NO2', 'NOx', 'O3', 'EstaciÃ³n',
#        'C7H8', 'C6H6', 'C8H10', 'Veloc.', 'Direc.', 'Temp.', 'H.Rel.',
#        'R.Sol.', 'Precip.', 'PM10', 'Pres.', 'PM2.5', 'PM1', 'Veloc.mÃ¡x.',
#        'H2S', 'NH3', 'PM10 s/c', 'PM2.5 s/c', 'PM1 s/c', 'Ruido', 'CH4'],
#       dtype='object')

# %%
df = df.rename(columns={'EstaciÃ³n':'Estacion',
                                   'Veloc.mÃ¡x.':'Veloc.max.'})
df.columns
# Out:
# Index(['FECHA', 'HORA', 'SO2', 'CO', 'NO', 'NO2', 'NOx', 'O3', 'Estacion',
#        'C7H8', 'C6H6', 'C8H10', 'Veloc.', 'Direc.', 'Temp.', 'H.Rel.',
#        'R.Sol.', 'Precip.', 'PM10', 'Pres.', 'PM2.5', 'PM1', 'Veloc.max.',
#        'H2S', 'NH3', 'PM10 s/c', 'PM2.5 s/c', 'PM1 s/c', 'Ruido', 'CH4'],
#       dtype='object')

# %%
corr = df.corr() # pearson
sns.heatmap(df.corr());
plt.show() # los de tipo object no los coge!!!!!!!!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890232 entries, 0 to 2890231
# Data columns (total 30 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   FECHA       object
#  1   HORA        int64
#  2   SO2         float64
#  3   CO          object
#  4   NO          float64
#  5   NO2         float64
#  6   NOx         float64
#  7   O3          float64
#  8   Estacion    object
#  9   C7H8        object
#  10  C6H6        object
#  11  C8H10       object
#  12  Veloc.      object
#  13  Direc.      float64
#  14  Temp.       object
#  15  H.Rel.      object
#  16  R.Sol.      float64
#  17  Precip.     object
#  18  PM10        float64
#  19  Pres.       float64
#  20  PM2.5       float64
#  21  PM1         float64
#  22  Veloc.max.  object
#  23  H2S         float64
#  24  NH3         float64
#  25  PM10 s/c    float64
#  26  PM2.5 s/c   float64
#  27  PM1 s/c     float64
#  28  Ruido       float64
#  29  CH4         object
# ...

# %%
df.describe()
# Out:
#                HORA           SO2            NO           NO2           NOx  \
# count  2.890232e+06  1.909681e+06  2.090175e+06  2.090116e+06  2.090279e+06
# mean   1.150542e+01  3.831046e+00  4.913923e+00  1.307648e+01  2.037430e+01
# std    6.922389e+00  2.987657e+00  1.309176e+01  1.532058e+01  3.200592e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.000000e+00  3.000000e+00  1.000000e+00  4.000000e+00  6.000000e+00
# 50%    1.200000e+01  3.000000e+00  2.000000e+00  7.000000e+00  1.000000e+01
# 75%    1.800000e+01  4.000000e+00  3.000000e+00  1.600000e+01  2.100000e+01
# max    2.300000e+01  2.690000e+02  5.320000e+02  2.390000e+02  9.870000e+02
#
#                  O3        Direc.        R.Sol.          PM10          Pres.  \
# count  2.339515e+06  1.443765e+06  1.132674e+06  1.291101e+06  789486.000000
# mean   6.073715e+01  1.963064e+02  1.875593e+02  1.521135e+01     979.982785
# ...
